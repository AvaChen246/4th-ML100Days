# %%
import keras
from keras.datasets import cifar10
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Conv2D, MaxPooling2D
from keras.optimizers import RMSprop, Adam
import os

os.environ["CUDA_VISIBLE_DEVICES"] = "0"

# %%
#Blas GEMM launch failed , 避免動態分配GPU / CPU, 出現問題
import tensorflow as tf
gpu_options = tf.compat.v1.GPUOptions(per_process_gpu_memory_fraction=0.333)
sess = tf.compat.v1.Session(config=tf.compat.v1.ConfigProto(gpu_options=gpu_options))

# %%
num_classes = 10 # 類別的數量，Cifar 10 共有 10 個類別
epochs = 50 # 訓練的 epochs 數量

# 讀取資料並檢視
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255
x_test /= 255
len_train= x_train.shape[0]
len_test = x_test.shape[0]
print('x_train shape:', x_train.shape)
print(len_train, 'train samples')
print(len_test, 'test samples')

# 對 label 進行 one-hot encoding (y_trian 原本是純數字)
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)
# Out:
# x_train shape: (50000, 32, 32, 3)
# 50000 train samples
# 10000 test samples

# %%
# train_batch_size = int(len_train/batchs)
# test_batch_size = int(len_test/batchs)

# %%
# 分批讀入compile
def cifar_generator(image_array, batch_size=100):
    while True:
        for indexs in range(0, len(image_array), batch_size): # range(start, stop[, step])
            images = x_train[indexs: indexs+batch_size]
            labels = y_train[indexs: indexs+batch_size]
            yield images, labels

# %%
def test_generator(image_array, batch_size=20):
    while True:
        for indexs in range(0, len(image_array), batch_size): # range(start, stop[, step])
            images = x_test[indexs: indexs+batch_size]
            labels = y_test[indexs: indexs+batch_size]
            yield images, labels

# %%
# 建立模型
keras.backend.clear_session() # 把舊的 Graph 清掉
model = Sequential()
model.add(Conv2D(32, (5, 5), padding='same',
                 input_shape=x_train.shape[1:]))
model.add(Activation('relu'))
model.add(Conv2D(32, (5, 5)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(64, (5, 5), padding='same'))
model.add(Activation('relu'))
model.add(Conv2D(64, (5, 5)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Flatten())
model.add(Dense(512))
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(num_classes))
model.add(Activation('softmax'))
model.summary()
model.compile(loss='categorical_crossentropy',
              optimizer=Adam(),
              metrics=['accuracy'])
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 32, 32, 32)        2432
# _________________________________________________________________
# activation_1 (Activation)    (None, 32, 32, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 28, 28, 32)        25632
# _________________________________________________________________
# activation_2 (Activation)    (None, 28, 28, 32)        0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 14, 14, 32)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 14, 14, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 14, 14, 64)        51264
# _________________________________________________________________
# activation_3 (Activation)    (None, 14, 14, 64)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 10, 10, 64)        102464
# _________________________________________________________________
# activation_4 (Activation)    (None, 10, 10, 64)        0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 5, 5, 64)          0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 5, 5, 64)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 1600)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               819712
# _________________________________________________________________
# activation_5 (Activation)    (None, 512)               0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                5130
# _________________________________________________________________
# activation_6 (Activation)    (None, 10)                0
# =================================================================
# Total params: 1,006,634
# Trainable params: 1,006,634
# Non-trainable params: 0
# _________________________________________________________________

# %%
cifar_gen = cifar_generator(x_train)
test_gen  = test_generator(x_test)

model.fit_generator(
                    cifar_gen,
                    steps_per_epoch= 100,
                    epochs=epochs,
                    verbose=1, 
                    validation_data = test_gen,
                    validation_steps = 100,
                    initial_epoch=0
                    )
    

score = model.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Epoch 1/50
# 100/100 [==============================] - 2s 20ms/step - loss: 2.0530 - accuracy: 0.2263 - val_loss: 2.0133 - val_accuracy: 0.3470
# Epoch 2/50
# 100/100 [==============================] - 2s 16ms/step - loss: 1.7276 - accuracy: 0.3584 - val_loss: 1.7222 - val_accuracy: 0.4320
# Epoch 3/50
# 100/100 [==============================] - 2s 17ms/step - loss: 1.5473 - accuracy: 0.4306 - val_loss: 1.3302 - val_accuracy: 0.4715
# Epoch 4/50
# 100/100 [==============================] - 2s 16ms/step - loss: 1.4854 - accuracy: 0.4566 - val_loss: 1.2148 - val_accuracy: 0.4900
# Epoch 5/50
# 100/100 [==============================] - 2s 16ms/step - loss: 1.4148 - accuracy: 0.4906 - val_loss: 1.2618 - val_accuracy: 0.5290
# Epoch 6/50
# 100/100 [==============================] - 2s 16ms/step - loss: 1.3230 - accuracy: 0.5223 - val_loss: 1.8032 - val_accuracy: 0.5670
# Epoch 7/50
# 100/100 [==============================] - 2s 16ms/step - loss: 1.2833 - accuracy: 0.5414 - val_loss: 1.4244 - val_accuracy: 0.5690
# Epoch 8/50
# 100/100 [==============================] - 2s 16ms/step - loss: 1.1964 - accuracy: 0.5726 - val_loss: 1.0506 - val_accuracy: 0.5995
# Epoch 9/50
# 100/100 [==============================] - 2s 16ms/step - loss: 1.1822 - accuracy: 0.5767 - val_loss: 0.9390 - val_accuracy: 0.6065
# Epoch 10/50
# 100/100 [==============================] - 2s 17ms/step - loss: 1.1212 - accuracy: 0.5994 - val_loss: 1.2829 - val_accuracy: 0.6245
# Epoch 11/50
# 100/100 [==============================] - 2s 16ms/step - loss: 1.0965 - accuracy: 0.6046 - val_loss: 1.3586 - val_accuracy: 0.6405
# Epoch 12/50
# 100/100 [==============================] - 2s 16ms/step - loss: 1.0621 - accuracy: 0.6233 - val_loss: 0.9664 - val_accuracy: 0.6280
# Epoch 13/50
# 100/100 [==============================] - 2s 17ms/step - loss: 1.0039 - accuracy: 0.6478 - val_loss: 0.7860 - val_accuracy: 0.6780
# Epoch 14/50
# 100/100 [==============================] - 2s 17ms/step - loss: 1.0098 - accuracy: 0.6417 - val_loss: 0.7512 - val_accuracy: 0.6905
# Epoch 15/50
# 100/100 [==============================] - 2s 17ms/step - loss: 0.9642 - accuracy: 0.6582 - val_loss: 1.3180 - val_accuracy: 0.6670
# Epoch 16/50
# 100/100 [==============================] - 2s 16ms/step - loss: 0.9632 - accuracy: 0.6612 - val_loss: 1.1293 - val_accuracy: 0.6930
# Epoch 17/50
# 100/100 [==============================] - 2s 16ms/step - loss: 0.9362 - accuracy: 0.6723 - val_loss: 0.7940 - val_accuracy: 0.6750
# Epoch 18/50
# 100/100 [==============================] - 2s 17ms/step - loss: 0.8961 - accuracy: 0.6862 - val_loss: 0.8197 - val_accuracy: 0.7175
# Epoch 19/50
# 100/100 [==============================] - 2s 17ms/step - loss: 0.9122 - accuracy: 0.6726 - val_loss: 0.7569 - val_accuracy: 0.6650
# Epoch 20/50
# 100/100 [==============================] - 2s 17ms/step - loss: 0.8741 - accuracy: 0.6865 - val_loss: 1.2815 - val_accuracy: 0.7045
# Epoch 21/50
# 100/100 [==============================] - 2s 17ms/step - loss: 0.8622 - accuracy: 0.6945 - val_loss: 0.9882 - val_accuracy: 0.7215
# Epoch 22/50
# 100/100 [==============================] - 2s 17ms/step - loss: 0.8531 - accuracy: 0.7038 - val_loss: 0.9858 - val_accuracy: 0.6780
# Epoch 23/50
# 100/100 [==============================] - 2s 17ms/step - loss: 0.8239 - accuracy: 0.7072 - val_loss: 0.8496 - val_accuracy: 0.7215
# Epoch 24/50
# 100/100 [==============================] - 2s 17ms/step - loss: 0.8488 - accuracy: 0.7050 - val_loss: 0.7184 - val_accuracy: 0.7270
# Epoch 25/50
# 100/100 [==============================] - 2s 17ms/step - loss: 0.8045 - accuracy: 0.7160 - val_loss: 1.1430 - val_accuracy: 0.7230
# Epoch 26/50
# 100/100 [==============================] - 2s 17ms/step - loss: 0.8284 - accuracy: 0.7104 - val_loss: 0.9729 - val_accuracy: 0.7520
# Epoch 27/50
# 100/100 [==============================] - 2s 17ms/step - loss: 0.8165 - accuracy: 0.7123 - val_loss: 0.7671 - val_accuracy: 0.7065
# Epoch 28/50
# 100/100 [==============================] - 2s 17ms/step - loss: 0.7554 - accuracy: 0.7374 - val_loss: 0.8365 - val_accuracy: 0.7455
# Epoch 29/50
# 100/100 [==============================] - 2s 17ms/step - loss: 0.7870 - accuracy: 0.7216 - val_loss: 0.7012 - val_accuracy: 0.7435
# Epoch 30/50
# 100/100 [==============================] - 2s 17ms/step - loss: 0.7596 - accuracy: 0.7342 - val_loss: 1.2785 - val_accuracy: 0.7160
# Epoch 31/50
# 100/100 [==============================] - 2s 17ms/step - loss: 0.7617 - accuracy: 0.7338 - val_loss: 0.9227 - val_accuracy: 0.7555
# Epoch 32/50
# 100/100 [==============================] - 2s 17ms/step - loss: 0.7582 - accuracy: 0.7390 - val_loss: 0.8869 - val_accuracy: 0.7300
# Epoch 33/50
# 100/100 [==============================] - 2s 17ms/step - loss: 0.7139 - accuracy: 0.7482 - val_loss: 0.6111 - val_accuracy: 0.7480
# Epoch 34/50
# 100/100 [==============================] - 2s 17ms/step - loss: 0.7440 - accuracy: 0.7383 - val_loss: 0.5789 - val_accuracy: 0.7510
# Epoch 35/50
# 100/100 [==============================] - 2s 17ms/step - loss: 0.7201 - accuracy: 0.7451 - val_loss: 1.0707 - val_accuracy: 0.7435
# Epoch 36/50
# 100/100 [==============================] - 2s 17ms/step - loss: 0.7274 - accuracy: 0.7411 - val_loss: 0.8796 - val_accuracy: 0.7635
# Epoch 37/50
# 100/100 [==============================] - 2s 17ms/step - loss: 0.7375 - accuracy: 0.7437 - val_loss: 0.8867 - val_accuracy: 0.7310
# Epoch 38/50
# 100/100 [==============================] - 2s 17ms/step - loss: 0.6941 - accuracy: 0.7562 - val_loss: 0.6669 - val_accuracy: 0.7630
# Epoch 39/50
# 100/100 [==============================] - 2s 17ms/step - loss: 0.6994 - accuracy: 0.7532 - val_loss: 0.7225 - val_accuracy: 0.7550
# Epoch 40/50
# 100/100 [==============================] - 2s 17ms/step - loss: 0.6690 - accuracy: 0.7610 - val_loss: 1.1646 - val_accuracy: 0.7560
# Epoch 41/50
# 100/100 [==============================] - 2s 17ms/step - loss: 0.6807 - accuracy: 0.7575 - val_loss: 0.8688 - val_accuracy: 0.7595
# Epoch 42/50
# 100/100 [==============================] - 2s 17ms/step - loss: 0.6952 - accuracy: 0.7554 - val_loss: 1.0226 - val_accuracy: 0.7425
# Epoch 43/50
# 100/100 [==============================] - 2s 17ms/step - loss: 0.6638 - accuracy: 0.7635 - val_loss: 0.7433 - val_accuracy: 0.7535
# Epoch 44/50
# 100/100 [==============================] - 2s 17ms/step - loss: 0.6822 - accuracy: 0.7624 - val_loss: 0.5735 - val_accuracy: 0.7655
# Epoch 45/50
# 100/100 [==============================] - 2s 17ms/step - loss: 0.6552 - accuracy: 0.7694 - val_loss: 1.1422 - val_accuracy: 0.7500
# Epoch 46/50
# 100/100 [==============================] - 2s 17ms/step - loss: 0.6402 - accuracy: 0.7748 - val_loss: 1.0071 - val_accuracy: 0.7630
# Epoch 47/50
# 100/100 [==============================] - 2s 17ms/step - loss: 0.6767 - accuracy: 0.7651 - val_loss: 0.9860 - val_accuracy: 0.7390
# Epoch 48/50
# 100/100 [==============================] - 2s 17ms/step - loss: 0.6494 - accuracy: 0.7727 - val_loss: 0.6622 - val_accuracy: 0.7655
# Epoch 49/50
# 100/100 [==============================] - 2s 17ms/step - loss: 0.6536 - accuracy: 0.7699 - val_loss: 0.4727 - val_accuracy: 0.7615
# Epoch 50/50
# 100/100 [==============================] - 2s 17ms/step - loss: 0.6211 - accuracy: 0.7820 - val_loss: 0.9607 - val_accuracy: 0.7695
# Test loss: 0.7225951750755311
# Test accuracy: 0.7605999708175659

# %% [markdown]
# optimizer=RMSprop()
# Test loss: 0.8466126122474671
# Test accuracy: 0.7486000061035156
# optimizer=Adam()
# Test loss: 0.7225951750755311
# Test accuracy: 0.7605999708175659
